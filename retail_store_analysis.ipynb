# %%
import pandas as pd

# %%
df=pd.read_csv("/content/retail_store_sales_dataset.csv")

# %%
df.head()
# Out:
#    transaction_id       city         store product_category product_name  \
# 0            5001       Pune  Central Mall       Home Decor   Face Cream
# 1            5002  Bangalore   City Center       Home Decor    Wall Lamp
# 2            5003  Hyderabad  Central Mall         Clothing        Jeans
# 3            5004  Hyderabad  Smart Bazaar       Home Decor        Mixer
# 4            5005  Hyderabad  Central Mall           Beauty   Headphones
#
#    unit_price  quantity customer_type payment_method  discount_percent  \
# 0        2386         4     Returning           Card                15
# 1        1383         1           New           Card                10
# 2        4937         1     Returning            UPI                 5
# 3        1470         2     Returning            UPI                10
# 4        2688         1           New           Cash                10
#
#    total_sale  discount_amount  final_amount
# 0        9544          1431.60       8112.40
# ...

# %%
df.shape   #How many transactions are recorded in the dataset?
# Out:
# (220, 13)

# %%
df["city"]    #What are the different cities present in the dataset?
# Out:
# 0           Pune
# 1      Bangalore
# 2      Hyderabad
# 3      Hyderabad
# 4      Hyderabad
#          ...
# 215    Hyderabad
# 216       Mysore
# 217         Pune
# 218      Chennai
# 219      Chennai
# Name: city, Length: 220, dtype: object

# %%
df["product_category"]   #How many product categories exist?
# Out:
# 0       Home Decor
# 1       Home Decor
# 2         Clothing
# 3       Home Decor
# 4           Beauty
#           ...
# 215     Home Decor
# 216         Beauty
# 217    Electronics
# 218      Groceries
# 219     Home Decor
# Name: product_category, Length: 220, dtype: object

# %%
df.head(10)    #Display the first 10 rows.
# Out:
#    transaction_id       city         store product_category product_name  \
# 0            5001       Pune  Central Mall       Home Decor   Face Cream
# 1            5002  Bangalore   City Center       Home Decor    Wall Lamp
# 2            5003  Hyderabad  Central Mall         Clothing        Jeans
# 3            5004  Hyderabad  Smart Bazaar       Home Decor        Mixer
# 4            5005  Hyderabad  Central Mall           Beauty   Headphones
# 5            5006     Mysore  Urban Retail      Electronics     Rice Bag
# 6            5007  Hyderabad    Metro Mart       Home Decor    Wall Lamp
# 7            5008    Chennai  Central Mall      Electronics        Mixer
# 8            5009       Pune  Central Mall      Electronics    Wall Lamp
# 9            5010  Bangalore   City Center       Home Decor    Wall Lamp
#
#    unit_price  quantity customer_type payment_method  discount_percent  \
# 0        2386         4     Returning           Card                15
# ...

# %%
df.info()   #Show the data types of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    220 non-null    int64
#  1   city              220 non-null    object
#  2   store             220 non-null    object
#  3   product_category  220 non-null    object
#  4   product_name      220 non-null    object
#  5   unit_price        220 non-null    int64
#  6   quantity          220 non-null    int64
#  7   customer_type     220 non-null    object
#  8   payment_method    220 non-null    object
#  9   discount_percent  220 non-null    int64
#  10  total_sale        220 non-null    int64
#  11  discount_amount   220 non-null    float64
#  12  final_amount      220 non-null    float64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 22.5+ KB

# %%
df["product_category"].value_counts().idxmax()   #Which product category is sold the most?
# Out:
# 'Groceries'

# %%
df.groupby("product_category")["quantity"].sum().idxmax()
# Out:
# 'Groceries'

# %%
df.groupby("store")["total_sale"].sum().idxmax()    #Which store has the highest number of transactions?
# Out:
# 'Smart Bazaar'

# %%
df["city"].value_counts().idxmax()    #Which city has the most customers?
# Out:
# 'Hyderabad'

# %%
df["final_amount"].mean()    #What is the average purchase value (final_amount)?
# Out:
# np.float64(5581.942045454545)

# %%
df["final_amount"].max()     #What is the maximum purchase value?
# Out:
# 19900.0

# %%
df.groupby("city")["final_amount"].sum().idxmax()     #Which city generates the highest revenue?
# Out:
# 'Hyderabad'

# %%
df["payment_method"].value_counts().idxmax()
# Out:
# 'Card'

# %%
df.groupby("customer_type")["final_amount"].sum().idxmax()
# Out:
# 'New'

# %%
df.groupby("product_category")["final_amount"].sum().idxmax()
# Out:
# 'Groceries'

# %%
df.groupby("store")["discount_amount"].sum().idxmax()
# Out:
# 'Smart Bazaar'

# %%
df.groupby("product_name")["quantity"].sum().idxmax()
# Out:
# 'Mixer'

# %%
df.groupby("city")["final_amount"].mean().idxmax()
# Out:
# 'Mysore'

# %%
cu_returning=df[df["customer_type"]=="Returning"]
cu_returning
# Out:
#      transaction_id       city         store product_category product_name  \
# 0              5001       Pune  Central Mall       Home Decor   Face Cream
# 2              5003  Hyderabad  Central Mall         Clothing        Jeans
# 3              5004  Hyderabad  Smart Bazaar       Home Decor        Mixer
# 5              5006     Mysore  Urban Retail      Electronics     Rice Bag
# 8              5009       Pune  Central Mall      Electronics    Wall Lamp
# ..              ...        ...           ...              ...          ...
# 211            5212       Pune  Central Mall        Groceries    Wall Lamp
# 212            5213  Hyderabad  Smart Bazaar         Clothing    Wall Lamp
# 213            5214     Mysore  Urban Retail      Electronics        Mixer
# 216            5217     Mysore  Urban Retail           Beauty     Rice Bag
# 219            5220    Chennai  Central Mall       Home Decor   Headphones
#
# ...

# %%
cu_returning.groupby("product_category")["customer_type"].sum().idxmax()
# Out:
# 'Groceries'

# %%
cu_returning["product_category"].value_counts().idxmax()
# Out:
# 'Groceries'
