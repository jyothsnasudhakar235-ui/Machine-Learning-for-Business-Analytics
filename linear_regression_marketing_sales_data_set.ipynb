# %%
import pandas as pd
import numpy as np

# %%
a=pd.read_csv("/content/marketing_sales_dataset.csv")

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   marketing_spend  200 non-null    int64
#  1   sales            200 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 3.3 KB

# %%
a.describe()
# Out:
#        marketing_spend         sales
# count       200.000000    200.000000
# mean       5720.335000  14653.033499
# std        2588.799649   6709.814180
# min        1064.000000    599.179062
# 25%        3546.250000   9189.740644
# 50%        6125.000000  14819.905725
# 75%        7970.500000  20559.740902
# max        9996.000000  28074.931600

# %%
a["marketing_spend"].mean()
# Out:
# np.float64(5720.335)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='marketing_spend', y='sales', data=a)
# Out:
# <Axes: xlabel='marketing_spend', ylabel='sales'>

# %%
#import ML model
from sklearn.linear_model import LinearRegression

# %%
x=a[['marketing_spend']]
y=a['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction = lr.predict(x_test)
y_prediction
# Out:
# array([20873.25712659, 15465.07459184,  7587.72184251, 11791.30919161,
#        14427.92313531, 22480.21709417,  5036.07934344, 15959.90829881,
#        16674.66809776, 20583.35455079, 19993.55275865, 22845.09447406,
#         4976.09950017,  3001.76299257, 20648.33271433,  3346.64709137,
#        20018.54436001, 11099.04183388,  7907.61433995, 24157.15354557,
#        18771.46345204, 18886.42481831,  4498.75991416, 23814.76860691,
#        22565.1885388 ,  5328.48107938, 15982.40074003, 22625.16838207,
#        20066.0284026 , 17624.34894952, 23639.82739737, 14225.49116428,
#        22807.60707202, 20855.76300564, 22820.1028727 , 21298.11434975,
#        16462.23948619, 16817.12022553, 14680.33830907, 16027.38562249])

# %%
#model evaluation
from sklearn.metrics import r2_score
print("R2_Score",r2_score(y_test,y_prediction))
# Out:
# R2_Score 0.9038233995267846

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x),color='red')

# %%
lr.coef_
# Out:
# array([2.49916014])

# %%
lr.intercept_
# Out:
# np.float64(342.65660764467975)

# %%
Y=(2.4787828*10)+473.5654939070628
Y
# Out:
# 498.35332190706276
